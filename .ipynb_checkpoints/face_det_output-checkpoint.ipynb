# %%
import pandas as pd

# %%
file_path = '../files/output/centerface_data.xlsx'
dfs = pd.read_excel(file_path, sheet_name=None)

artifacts_df = dfs['Pipeline Artifacts']
sizes_df = dfs['Detection Sizes']

# %%
sizes_df.describe()
# Out:
#                idx           w           h             a
# count   232.000000  232.000000  232.000000    232.000000
# mean   2125.517241   41.590517   62.168103   3302.935345
# std    1511.148954   23.544569   32.231605   5307.600841
# min       0.000000   16.000000   22.000000    462.000000
# 25%     840.000000   28.000000   49.000000   1313.000000
# 50%    1820.000000   37.000000   60.000000   2262.500000
# 75%    3265.000000   44.000000   66.000000   2884.500000
# max    5540.000000  161.000000  241.000000  36873.000000

# %%
len(sizes_df.loc[sizes_df['a'] > (47*47)])
# Out:
# 118
